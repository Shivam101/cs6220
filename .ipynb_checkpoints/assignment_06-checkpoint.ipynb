# %%
import matplotlib.pyplot as pl
import numpy as np
from sklearn import datasets, linear_model
import pandas as pd
fileURL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris=pd.read_csv(fileURL, names=['Sepal_Length', 'Sepal_Width','Petal_Length','Petal_Width','Species'],header=None)
iris = iris.dropna()

# %%
iris[:5]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
# %pylab inline

# (c) 2014 Reid Johnson and Everaldo Aguiar
#
# Functions to work with continuous data and linear regression models.

import matplotlib.pyplot as pl

def pairs(data):
    """Generates and shows a pairwise scatterplot of the dataset features.

    A figure with nxn scatterplots is generated, where n is the number of features. The features are
    defined as the all columns excluding the final column, which is defined as the class.

    Args:
      data (array): A dataset.

    """
    i = 1

    # Divide columns into features and class.
    features = list(data.columns)
    classes = features[-1] # create class column
    del features[-1] # delete class column from feature vector

    # Generate an nxn subplot figure, where n is the number of features.
    figure = pl.figure(figsize=(5*(len(data.columns)-1), 4*(len(data.columns)-1)))
    for col1 in data[features]:
        for col2 in data[features]:
            ax = pl.subplot(len(data.columns)-1, len(data.columns)-1, i)
            if col1 == col2:
                print col1
                print col2
                ax.text(2.5, 4.5, col1, style='normal', fontsize=20)
                ax.axis([0, 10, 0, 10])
                pl.xticks([]), pl.yticks([])
            else:
                for name in data[classes]:
                    cond = data[classes] == name
                    ax.plot(data[col2][cond], data[col1][cond], linestyle='none', marker='o', label=name)
                #t = plt.title(name)
            i += 1

    pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pairs(iris)
# Out:
# Sepal_Length
# Sepal_Length
# Sepal_Width
# Sepal_Width
# Petal_Length
# Petal_Length
# Petal_Width
# Petal_Width

# %%
 # Divide columns into features and class.
features = list(iris.columns)
classes = features[-1] # create class column
del features[-1] # delete class column from feature vector

# %%
features
# Out:
# ['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width']

# %%
classes
# Out:
# 'Species'

# %% [markdown]
# A Plot of the linear regression models generated on each pairwise combination of features, with corresponding model statistics:

# %%
from sklearn.cross_validation import train_test_split
train, test= train_test_split(iris)

def linear_regression_plot(iris, feature1, feature2):
    # Split the data into training/testing sets

    train_feature1 = train.ix[:, feature1]
    train_feature2 = train.ix[:, feature2]
    test_feature1 = test.ix[:, feature1]
    test_feature2 = test.ix[:, feature2]
    
    
    #call linear regression model
    regr = linear_model.LinearRegression()
    regr.fit(train_feature1,train_feature2)
    
    pl.plot(test_feature1, regr.predict(test_feature1), color='blue',linewidth=3)
    
    for name in iris[classes]:
                    cond = iris[classes] == name
                    pl.plot(test[features[feature1[0]]][cond], test[features[feature2[0]]][cond], linestyle='none', marker='o', label=name)
                
    # The coefficients
    print('Coefficients:', regr.coef_)
    # The mean squared error
    print("Mean squared error: %.2f"
          % np.mean((regr.predict(test_feature1) - test_feature2) ** 2))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(test_feature1, test_feature2))
    print('features:',feature1[0], feature2[0] )
    # Plot outputs
    plt.xlabel(features[feature1[0]])
    plt.ylabel(features[feature2[0]])
    pl.xticks(())
    pl.yticks(())


    pl.show()

# %%
for x in range(4):
    for y in range(4):
     if(x != y):
        linear_regression_plot(iris,(x,), (y,))
# Out:
# ('Coefficients:', array([[-0.05928136]]))
# Mean squared error: 0.25
# Variance score: -0.06
# ('features:', 0, 1)
# ('Coefficients:', array([[ 1.85732007]]))
# Mean squared error: 0.85
# Variance score: 0.64
# ('features:', 0, 2)
# ('Coefficients:', array([[ 0.75099134]]))
# Mean squared error: 0.18
# Variance score: 0.57
# ('features:', 0, 3)
# ('Coefficients:', array([[-0.26358108]]))
# Mean squared error: 0.52
# Variance score: -0.21
# ('features:', 1, 0)
# ('Coefficients:', array([[-1.82930042]]))
# Mean squared error: 2.20
# Variance score: 0.06
# ('features:', 1, 2)
# ('Coefficients:', array([[-0.68615527]]))
# Mean squared error: 0.44
# Variance score: -0.07
# ('features:', 1, 3)
# ('Coefficients:', array([[ 0.42253679]]))
# Mean squared error: 0.18
# Variance score: 0.59
# ('features:', 2, 0)
# ('Coefficients:', array([[-0.09359804]]))
# Mean squared error: 0.21
# Variance score: 0.12
# ('features:', 2, 1)
# ('Coefficients:', array([[ 0.41741413]]))
# Mean squared error: 0.03
# Variance score: 0.92
# ('features:', 2, 3)
# ('Coefficients:', array([[ 0.90698828]]))
# Mean squared error: 0.19
# Variance score: 0.56
# ('features:', 3, 0)
# ('Coefficients:', array([[-0.18637733]]))
# Mean squared error: 0.22
# Variance score: 0.06
# ('features:', 3, 1)
# ('Coefficients:', array([[ 2.2159304]]))
# Mean squared error: 0.17
# Variance score: 0.93
# ('features:', 3, 2)

# %% [raw]
# The pair of features petal_length and pental Width has the greatest variance score 0.90.

# %% [markdown]
# A plot of the best overall linear regression model you were able to generate using any combination of features(including the use of multiple features used in combination to predict a single feature), with corresponding model statistics.

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
trainSet, testSet= train_test_split(iris)
train_X = trainSet.ix[:, 0:4]
train_Y = trainSet.ix[:,4]
test_X = testSet.ix[:,0:4]
test_Y = testSet.ix[:,4]

# %%
train_X[:5]
# Out:
#     Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 88           5.6          3.0           4.1          1.3
# 35           5.0          3.2           1.2          0.2
# 78           6.0          2.9           4.5          1.5
# 17           5.1          3.5           1.4          0.3
# 98           5.1          2.5           3.0          1.1

# %%
test_X[:5]
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 48            5.3          3.7           1.5          0.2
# 34            4.9          3.1           1.5          0.1
# 8             4.4          2.9           1.4          0.2
# 66            5.6          3.0           4.5          1.5
# 144           6.7          3.3           5.7          2.5

# %%
ols = linear_model.LinearRegression()

# %%
import itertools as iter
def allCombination(l,nums):
    return list(iter.permutations(l,nums))

# %%
def plot_figs(fig_num, elev, azim, train_X,test_X, clf,combination):
    clf.fit(train_X.ix[:,(combination[0],combination[1])], train_X.ix[:,combination[2]])
    fig = plt.figure(fig_num, figsize=(6, 5))
    plt.clf()
    params = clf.coef_
    a = params[0]
    b = params[1]
    c = clf.intercept_
    ax = Axes3D(fig, elev=elev, azim=azim)
    x = test_X.ix[:, 0]
    y = test_X.ix[:, 1]
    z = clf.predict(test_X.ix[:,(0,1)])
    #print x
    #print y
    #print z
    # convert to 2d matrices
    X, Y = np.meshgrid(x, y) 
    zs= np.array([fun(x,a,y,b,c) for x,y in zip(np.ravel(X), np.ravel(Y))])
    Z = zs.reshape(X.shape)
    
    ax.scatter(test_X.ix[:, combination[0]], test_X.ix[:, combination[1]], test_X.ix[:, combination[2]], c='k', marker='+', cmap=plt.cm.Paired)
    ax.plot_surface(X,Y,Z,rstride=1, cstride=1,alpha=0.2,cmap=cm.coolwarm,
    linewidth=0, antialiased=False)

    ax.set_xlabel(features[combination[0]])
    ax.set_ylabel(features[combination[1]])
    ax.set_zlabel(features[combination[2]])
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    
    
    print('Coefficients:', clf.coef_)
    print('Intercept:',c)
    # The mean squared error
    mse = np.mean((z-test_X.ix[:, 2])**2)
    print("Mean squared error: %.2f"
          % mse)
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % clf.score(test_X.ix[:,(0,1)], test_X.ix[:, 2]))
    
    return mse, combination
     
    
def fun(x,a,y,b,c):
    return x*a + y*b + c

# %%
allCom =  allCombination([0,1,2,3], 3)

finalMSE = float("inf")
finalCombination = None
for com in allCom:
    #Generate the three different figures from different views
    elev = -.5
    azim = 90
    mse,combination = plot_figs(1, elev, azim, train_X,test_X, ols,com)
    if(mse < finalMSE):
        finalMSE = mse
        finalCombination = combination
    plt.show()

    
print ("smallest MSE in three features combination: %.2f" % finalMSE)
print (" three features: ", finalCombination )
print ("feature1: ", features[finalCombination[0]])
print ("feature2: ", features[finalCombination[1]])
print ("feature3: ", features[finalCombination[2]])
# Out:
# ('Coefficients:', array([ 1.78478263, -1.33374884]))
# ('Intercept:', -2.6191655516785159)
# Mean squared error: 0.35
# Variance score: 0.89
# ('Coefficients:', array([ 0.74111363, -0.47545301]))
# ('Intercept:', -1.6842695435633541)
# Mean squared error: 7.82
# Variance score: -1.50
# ('Coefficients:', array([ 0.55159406, -0.32425202]))
# ('Intercept:', 1.0381830178017339)
# Mean squared error: 1.92
# Variance score: 0.38
# ('Coefficients:', array([-0.06394759,  0.44780762]))
# ('Intercept:', -0.10627966676519263)
# Mean squared error: 11.42
# Variance score: -2.65
# ('Coefficients:', array([ 0.29868209, -0.45360075]))
# ('Intercept:', 1.8445028406293105)
# Mean squared error: 4.43
# Variance score: -0.42
# ('Coefficients:', array([ 0.50622745,  1.75731252]))
# ('Intercept:', -1.3163570198687973)
# Mean squared error: 14.82
# Variance score: -3.74
# ('Coefficients:', array([-1.33374884,  1.78478263]))
# ('Intercept:', -2.6191655516785231)
# Mean squared error: 82.71
# Variance score: -25.48
# ('Coefficients:', array([-0.47545301,  0.74111363]))
# ('Intercept:', -1.6842695435633577)
# Mean squared error: 39.32
# Variance score: -11.59
# ('Coefficients:', array([ 0.59241974,  0.46601931]))
# ('Intercept:', 2.2957129115577364)
# Mean squared error: 14.20
# Variance score: -3.55
# ('Coefficients:', array([ 0.10661171,  0.43242976]))
# ('Intercept:', -0.74770089525984917)
# Mean squared error: 9.38
# Variance score: -2.00
# ('Coefficients:', array([ 0.40334416,  0.95481128]))
# ('Intercept:', 3.476392298049289)
# Mean squared error: 28.60
# Variance score: -8.16
# ('Coefficients:', array([-0.35451522,  2.13368219]))
# ('Intercept:', 2.2747419587267892)
# Mean squared error: 16.19
# Variance score: -4.18
# ('Coefficients:', array([-0.32425202,  0.55159406]))
# ('Intercept:', 1.0381830178017339)
# Mean squared error: 12.51
# Variance score: -3.00
# ('Coefficients:', array([ 0.44780762, -0.06394759]))
# ('Intercept:', -0.10627966676519041)
# Mean squared error: 4.02
# Variance score: -0.29
# ('Coefficients:', array([ 0.46601931,  0.59241974]))
# ('Intercept:', 2.2957129115577337)
# Mean squared error: 12.30
# Variance score: -2.94
# ('Coefficients:', array([ 0.43242976,  0.10661171]))
# ('Intercept:', -0.74770089525984962)
# Mean squared error: 4.78
# Variance score: -0.53
# ('Coefficients:', array([ 0.51445259, -0.25502417]))
# ('Intercept:', 4.2259836244256679)
# Mean squared error: 9.26
# Variance score: -1.97
# ('Coefficients:', array([-0.26678903,  0.39586958]))
# ('Intercept:', 3.574578060191115)
# Mean squared error: 4.38
# Variance score: -0.40
# ('Coefficients:', array([-0.45360075,  0.29868209]))
# ('Intercept:', 1.84450284062931)
# Mean squared error: 17.29
# Variance score: -4.53
# ('Coefficients:', array([ 1.75731252,  0.50622745]))
# ('Intercept:', -1.316357019868799)
# Mean squared error: 46.18
# Variance score: -13.78
# ('Coefficients:', array([ 0.95481128,  0.40334416]))
# ('Intercept:', 3.4763922980492876)
# Mean squared error: 44.50
# Variance score: -13.25
# ('Coefficients:', array([ 2.13368219, -0.35451522]))
# ('Intercept:', 2.2747419587267883)
# Mean squared error: 97.42
# Variance score: -30.19
# ('Coefficients:', array([-0.25502417,  0.51445259]))
# ('Intercept:', 4.2259836244256697)
# Mean squared error: 4.67
# Variance score: -0.50
# ('Coefficients:', array([ 0.39586958, -0.26678903]))
# ('Intercept:', 3.5745780601911141)
# Mean squared error: 3.88
# Variance score: -0.24
# smallest MSE in three features combination: 0.35
# (' three features: ', (0, 1, 2))
# ('feature1: ', 'Sepal_Length')
# ('feature2: ', 'Sepal_Width')
# ('feature3: ', 'Petal_Length')

# %% [markdown]
#  It shows that using two features 'Sepal_Length' and 'Sepal_Width' to predict 'Petal_length' gives us 0.35 MSE, however
# the pair of features petal_length and pental Width has the smallest MSE 0.03.

# %%
linear_regression_plot(iris,(2,), (3,))
# Out:
# ('Coefficients:', array([[ 0.41741413]]))
# Mean squared error: 0.03
# Variance score: 0.92
# ('features:', 2, 3)

# %% [markdown]
# If removing petal_width, which shows the best predictive feature in pairs, it still does not have much affect on classification. Since based on our three features model, features sepal length, sepal width and petal length can also perform classification.
